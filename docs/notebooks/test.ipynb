# %% [markdown]
# # TODO - remove this notebook
#
# Remove this notebook when we can replace with a real one; this is just to test our automated test.

# %%
print("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
plt.plot([0,2,3], [0,1,4], 'o')
